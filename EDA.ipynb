# %%
import pandas as pd

# 파일 경로 설정
temperature_accum_path = 'C:/Users/82106/Desktop/데이터 분석 프로젝트 2/날씨 빅데이터 콘테스트/데이터/서울 적산온도 데이터.csv'
temperature_analysis_path = 'C:/Users/82106/Desktop/데이터 분석 프로젝트 2/날씨 빅데이터 콘테스트/데이터/서울시 기온분석.csv'
wind_analysis_path = 'C:/Users/82106/Desktop/데이터 분석 프로젝트 2/날씨 빅데이터 콘테스트/데이터/서울시 바람 분석.csv'
humidity_analysis_path = 'C:/Users/82106/Desktop/데이터 분석 프로젝트 2/날씨 빅데이터 콘테스트/데이터/서울시 습도 분석.csv'
sunshine_solar_path = 'C:/Users/82106/Desktop/데이터 분석 프로젝트 2/날씨 빅데이터 콘테스트/데이터/서울시 일조일사 데이터.csv'
precipitation_path = 'C:/Users/82106/Desktop/데이터 분석 프로젝트 2/날씨 빅데이터 콘테스트/데이터/서울시 강수량 데이터.csv'

# 각 파일을 cp949 인코딩과 적절한 skiprows 옵션을 사용하여 로드
temperature_accum = pd.read_csv(temperature_accum_path, encoding='cp949', skiprows=3)
temperature_analysis = pd.read_csv(temperature_analysis_path, encoding='cp949', skiprows=7)
wind_analysis = pd.read_csv(wind_analysis_path, encoding='cp949', skiprows=15)
humidity_analysis = pd.read_csv(humidity_analysis_path, encoding='cp949', skiprows=16)
sunshine_solar = pd.read_csv(sunshine_solar_path, encoding='cp949', skiprows=17)
precipitation = pd.read_csv(precipitation_path, encoding='cp949',skiprows=7)

# 필요한 경우, 열 이름 변경 및 날짜 형식 변환
temperature_accum.rename(columns={'년도': '날짜'}, inplace=True)
temperature_accum['날짜'] = pd.to_datetime(temperature_accum['날짜'], format='%Y')

temperature_analysis['날짜'] = pd.to_datetime(temperature_analysis['날짜'].str.strip(), format='%Y-%m-%d')

# wind_analysis 등 다른 데이터 프레임에도 같은 방식으로 적용
# '일시' 또는 다른 열 이름이 날짜로 사용된 경우 해당 열 이름을 '날짜'로 변경
wind_analysis.rename(columns={'일시': '날짜'}, inplace=True)
wind_analysis['날짜'] = pd.to_datetime(wind_analysis['날짜'].str.strip(), format='%Y-%m-%d')

humidity_analysis.rename(columns={'일시': '날짜'}, inplace=True)
humidity_analysis['날짜'] = pd.to_datetime(humidity_analysis['날짜'].str.strip(), format='%Y-%m-%d')

sunshine_solar.rename(columns={'일시': '날짜'}, inplace=True)
sunshine_solar['날짜'] = pd.to_datetime(sunshine_solar['날짜'].str.strip(), format='%Y-%m-%d')

precipitation['날짜'] = pd.to_datetime(precipitation['날짜'].str.strip(), format='%Y-%m-%d')

# %%
# 각 데이터셋의 칼럼 출력
print("적산온도 데이터 칼럼:", temperature_accum.columns)
print("기온분석 데이터 칼럼:", temperature_analysis.columns)
print("바람 분석 데이터 칼럼:", wind_analysis.columns)
print("습도 분석 데이터 칼럼:", humidity_analysis.columns)
print("일조일사 데이터 칼럼:", sunshine_solar.columns)
print("강수량 데이터 칼럼:", precipitation.columns)
# Out:
# 적산온도 데이터 칼럼: Index(['날짜', '일수', '값'], dtype='object')
# 기온분석 데이터 칼럼: Index(['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)'], dtype='object')
# 바람 분석 데이터 칼럼: Index(['\t\t지점번호', '지점명', '날짜', '평균풍속(m/s)', '최대풍속(m/s)', '최대풍속풍향(deg)',
#        '\t최대풍속시각', '최대순간풍속(m/s)', '최대순간풍속풍향(deg)', '\t최대순간풍속시각'],
#       dtype='object')
# 습도 분석 데이터 칼럼: Index(['\t\t지점번호', '지점명', '날짜', '평균습도(%rh)', '최저습도(%rh)'], dtype='object')
# 일조일사 데이터 칼럼: Index(['\t\t지점번호', '지점명', '날짜', '일조합(hr)', '일조율(%)', '일사합(MJ/m2)'], dtype='object')
# 강수량 데이터 칼럼: Index(['날짜', '지점', '강수량(mm)'], dtype='object')

# %%
#한글폰트
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 경로 설정
font_path = 'C:/Windows/Fonts/malgun.ttf'  # 여기서 'malgun.ttf'는 예시로 사용한 것이며, 실제 한글 폰트 파일로 변경해야 합니다.
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rc('font', family=font_name)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 기초 통계 요약 및 결측치 확인
def summarize_data(df):
    print("Summary Statistics:")
    print(df.describe())
    print("\nMissing Values Count:")
    print(df.isnull().sum())

# 데이터 분포 시각화
def plot_histograms(df, columns):
    for column in columns:
        plt.figure(figsize=(10, 4))
        df[column].hist(bins=30)
        plt.title(f'Histogram of {column}')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        plt.grid(False)
        plt.show()

# 시계열 데이터 시각화
def plot_time_series(df, date_col, value_col):
    plt.figure(figsize=(12, 5))
    plt.plot(df[date_col], df[value_col], marker='o', linestyle='-')
    plt.title(f'Time Series Plot of {value_col}')
    plt.xlabel('Date')
    plt.ylabel(value_col)
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# 각 데이터셋에 대해 함수 호출
print("Analysis of Accumulated Temperature Data")
summarize_data(temperature_accum)
plot_histograms(temperature_accum, ['값'])
plot_time_series(temperature_accum, '날짜', '값')

print("Analysis of Temperature Data")
summarize_data(temperature_analysis)
plot_histograms(temperature_analysis, ['평균기온(℃)', '최저기온(℃)', '최고기온(℃)'])
plot_time_series(temperature_analysis, '날짜', '평균기온(℃)')

# 필요한 경우, 다른 데이터셋에 대해서도 유사하게 분석을 진행할 수 있다.
# Out:
# Analysis of Accumulated Temperature Data
# Summary Statistics:
#                                   날짜           일수            값
# count                           9132  9132.000000  9132.000000
# mean   2012-01-01 08:38:00.157687296   183.140276  1512.601856
# min              2000-01-01 00:00:00     1.000000     0.000000
# 25%              2006-01-01 00:00:00    92.000000    53.500000
# 50%              2012-01-01 00:00:00   183.000000  1147.375000
# 75%              2018-01-01 00:00:00   274.000000  3044.675000
# max              2024-01-01 00:00:00   366.000000  3803.700000
# std                              NaN   105.453110  1393.539633
#
# Missing Values Count:
# 날짜    0
# 일수    0
# 값     0
# dtype: int64
# Analysis of Temperature Data
# Summary Statistics:
#                         날짜      지점      평균기온(℃)      최저기온(℃)      최고기온(℃)
# count                 8895  8895.0  8895.000000  8894.000000  8894.000000
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 상자 그림 시각화
def plot_boxplots(df, columns):
    for column in columns:
        plt.figure(figsize=(8, 4))
        sns.boxplot(x=df[column])
        plt.title(f'Boxplot of {column}')
        plt.grid(True)
        plt.show()

# 산점도 행렬 생성
def plot_scatter_matrix(df, columns):
    sns.pairplot(df[columns])
    plt.suptitle('Scatter Plot Matrix', y=1.02)
    plt.show()

# 상관 계수 행렬 시각화
def plot_correlation_matrix(df, columns):
    corr_matrix = df[columns].corr()
    plt.figure(figsize=(8, 6))
    sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
    plt.title('Correlation Matrix')
    plt.show()

print("Analysis of Accumulated Temperature Data")
plot_boxplots(temperature_accum, ['값'])

print("Analysis of Temperature Data")
plot_boxplots(temperature_analysis, ['평균기온(℃)', '최저기온(℃)', '최고기온(℃)'])
plot_scatter_matrix(temperature_analysis, ['평균기온(℃)', '최저기온(℃)', '최고기온(℃)'])
plot_correlation_matrix(temperature_analysis, ['평균기온(℃)', '최저기온(℃)', '최고기온(℃)'])
# Out:
# Analysis of Accumulated Temperature Data
# Analysis of Temperature Data
# C:\Users\82106\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82106\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82106\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
# 기온 분석 데이터셋
print("Temperature Analysis Data")
plot_boxplots(temperature_analysis, ['평균기온(℃)', '최저기온(℃)', '최고기온(℃)'])
plot_scatter_matrix(temperature_analysis, ['평균기온(℃)', '최저기온(℃)', '최고기온(℃)'])
plot_correlation_matrix(temperature_analysis, ['평균기온(℃)', '최저기온(℃)', '최고기온(℃)'])


# 바람 분석 데이터셋
print("Wind Analysis Data")
plot_boxplots(wind_analysis, ['평균풍속(m/s)', '최대풍속(m/s)', '최대순간풍속(m/s)'])
plot_scatter_matrix(wind_analysis, ['평균풍속(m/s)', '최대풍속(m/s)', '최대순간풍속(m/s)'])
plot_correlation_matrix(wind_analysis, ['평균풍속(m/s)', '최대풍속(m/s)', '최대순간풍속(m/s)'])


# 습도 분석 데이터셋
print("Humidity Analysis Data")
plot_boxplots(humidity_analysis, ['평균습도(%rh)', '최저습도(%rh)'])
plot_scatter_matrix(humidity_analysis, ['평균습도(%rh)', '최저습도(%rh)'])
plot_correlation_matrix(humidity_analysis, ['평균습도(%rh)', '최저습도(%rh)'])


# 일조일사 데이터셋
print("Sunshine and Solar Radiation Data")
plot_boxplots(sunshine_solar, ['일조합(hr)', '일사합(MJ/m2)'])
plot_scatter_matrix(sunshine_solar, ['일조합(hr)', '일사합(MJ/m2)'])
plot_correlation_matrix(sunshine_solar, ['일조합(hr)', '일사합(MJ/m2)'])


# 강수량 데이터셋
print("Precipitation Data")
plot_boxplots(precipitation, ['강수량(mm)'])
# Out:
# Temperature Analysis Data
# C:\Users\82106\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82106\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\82106\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\82106\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# ...
